# %%
import numpy as np
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %%
x, y = make_regression(100, 1, noise=5, bias=5)
x += 3
y = y**2

# %%
plt.figure(figsize=(12, 6))
plt.scatter(x, y)
plt.xlabel("features")
plt.ylabel("labels")
plt.title("Test Regression Data")
plt.show()

# %%
from linear.regression import LinearRegressor, PolynomialRegressor
from kernel.regression import KernelRegressor
from neighbors.regression import KNNRegressor

# %%
LR = LinearRegressor()

# %%
LR.fit(x, y)

# %%
plt.figure(figsize=(12, 6))
plt.scatter(x, y)
plt.xlabel("features")
plt.ylabel("labels")
plt.title("Test Regression Data")
plt.plot(x[np.argsort(x.reshape(-1))], LR.predict(x)[np.argsort(x.reshape(-1))], 'r')
plt.legend(["Actual", "Predicted"])
plt.show()

# %%
PR = PolynomialRegressor(2)

# %%
PR.fit(x, y)

# %%
plt.figure(figsize=(12, 6))
plt.scatter(x, y)
plt.xlabel("features")
plt.ylabel("labels")
plt.title("Test Regression Data")
plt.plot(x[np.argsort(x.reshape(-1))], PR.predict(x)[np.argsort(x.reshape(-1))], c="r")
plt.legend(["Actual", "Predicted"])
plt.show()

# %%
NR = KNNRegressor(k=3)

# %%
NR.fit(x, y)

# %%
plt.figure(figsize=(12, 6))
plt.scatter(x, y)
plt.xlabel("features")
plt.ylabel("labels")
plt.title("Test Regression Data")
plt.plot(x[np.argsort(x.reshape(-1))], np.array(NR.predict(x))[np.argsort(x.reshape(-1))], c="r")
plt.legend(["Actual", "Predicted"])
plt.show()

# %%
KR1 = KernelRegressor(kernel='linear')
KR2 = KernelRegressor(kernel='poly')
KR3 = KernelRegressor(kernel='rbf')

# %%
KR1.fit(x, y)
KR2.fit(x, y, bias=1, degree=2)
KR3.fit(x, y, sigma=0.5)

# %%
plt.figure(figsize=(12, 6))
plt.scatter(x, y)
plt.xlabel("features")
plt.ylabel("labels")
plt.title("Test Regression Data")
plt.plot(x[np.argsort(x.reshape(-1))], KR1.predict(x)[np.argsort(x.reshape(-1))], c="r")
plt.plot(x[np.argsort(x.reshape(-1))], KR2.predict(x, bias=1, degree=2)[np.argsort(x.reshape(-1))], c="g")
plt.plot(x[np.argsort(x.reshape(-1))], KR3.predict(x, sigma=0.5)[np.argsort(x.reshape(-1))], c="orange")
plt.legend(["Actual", "Linear Kernel", "Polynomial Kernel", "Gaussian Kernel"])
plt.show()
